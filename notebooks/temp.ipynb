# %%
import os

# Move from notebooks/ to the project root
os.chdir("..")

# %%
from src.config import FEATURE_NAMES_PATH
import joblib

feature_names = joblib.load(FEATURE_NAMES_PATH)

print(len(feature_names))
print(feature_names[:10])
# Out:
# 265
# ['Order', 'PID', 'Lot Frontage', 'Lot Area', 'Lot Shape', 'Utilities', 'Land Slope', 'Overall Qual', 'Overall Cond', 'Year Built']
